# %%
best_mlp ={
        "epochs": 10,
        "lr": 0.01,
        "hidden": 256,
        "weight_decay": 0.001,
        "train loss arc": [
            2.180646953076871,
            2.032512507188092,
            1.9801633725444674,
            1.9777896003688427,
            1.9173695842851728,
            1.813838285801406,
            1.7678458402385635,
            1.7042605343774615,
            1.7548799645845,
            1.8176999086841807
        ],
        "val loss arc": [
            1.8676497141520183,
            1.8739041279564845,
            2.079406547097339,
            1.7339266182932382,
            1.6089918331281903,
            1.6322422353201547,
            1.640492958862645,
            1.6747542011260521,
            1.6568306242426236,
            1.4472248046969374
        ],
        "val accuracies": [
            0.4,
            0.4166666666666667,
            0.4166666666666667,
            0.5166666666666667,
            0.45,
            0.48333333333333334,
            0.4666666666666667,
            0.5333333333333333,
            0.45,
            0.5333333333333333
        ],
        "Final Accuracy": 0.5333333333333333
    }

# %%
best_GCN = {
        "epochs": 50,
        "lr": 0.0001,
        "layers": 4,
        "layer norm": True,
        "hidden": 128,
        "dropout": 0.3,
        "weight_decay": 0.0001,
        "train loss arc": [
            1.7917950632671515,
            1.6580809662739435,
            1.561115807791551,
            1.4572696269800265,
            1.3888150008084874,
            1.3335156437785676,
            1.2663419645279645,
            1.2099307414454719,
            1.172511553298682,
            1.1103860971440251,
            1.0678602998222535,
            1.037455009086989,
            0.9814617916475982,
            0.9590510639672478,
            0.9296668047124209,
            0.8809159975731745,
            0.86453588619673,
            0.8000655442747908,
            0.777259835220563,
            0.746977379230278,
            0.726377248505014,
            0.6871339513929949,
            0.6584269745345712,
            0.6204656435952832,
            0.6200770142982946,
            0.5870309889636701,
            0.5565836895577376,
            0.5221989656069733,
            0.4992846340552205,
            0.4637203829656452,
            0.46108429562094294,
            0.4317619875429955,
            0.4252319244396252,
            0.3715211478758041,
            0.3548741256363428,
            0.34872926884815264,
            0.32585752373931126,
            0.3065168035331832,
            0.29025976242931695,
            0.25862144512060087,
            0.2695231952181227,
            0.22936784684970918,
            0.23924119175626402,
            0.2051193232753576,
            0.21229271981683268,
            0.2139869996841147,
            0.15605468821513568,
            0.1766467087090253,
            0.17494898535556633,
            0.16188453626894747
        ],
        "val loss arc": [
            1.6913328111171722,
            1.6088925530513127,
            1.572880952556928,
            1.5269469703237215,
            1.4914534424742063,
            1.453965404133002,
            1.4193276358147462,
            1.388483703136444,
            1.3543781953553358,
            1.3461783689757187,
            1.3368449330329895,
            1.314090449611346,
            1.3004872143268584,
            1.2713845542321602,
            1.254480160648624,
            1.2671930026262999,
            1.2253734358896813,
            1.2514081409201026,
            1.2607489694530765,
            1.2303916223968068,
            1.2420982134838898,
            1.2209527554611366,
            1.2154045348986984,
            1.2272998744311432,
            1.2591196523979307,
            1.2155405774402122,
            1.1833864802028984,
            1.2183711228736986,
            1.2226233802270143,
            1.230665281166633,
            1.1816582832563047,
            1.2887904184404761,
            1.2594930869759993,
            1.252318421487386,
            1.2377812903141603,
            1.227323830112194,
            1.228334224076631,
            1.24481769745859,
            1.2594385131533878,
            1.2537300283787771,
            1.2011971517271982,
            1.273193119512871,
            1.279676580877276,
            1.2778982284168403,
            1.2662725035954887,
            1.2854822513239923,
            1.3056703697696017,
            1.3010222490304537,
            1.2843334372815056,
            1.2579307124949992
        ],
        "val accuracies": [
            0.38333333333333336,
            0.5166666666666667,
            0.5,
            0.48333333333333334,
            0.4666666666666667,
            0.5166666666666667,
            0.5,
            0.5,
            0.5166666666666667,
            0.5333333333333333,
            0.5333333333333333,
            0.55,
            0.6333333333333333,
            0.5833333333333334,
            0.6,
            0.6166666666666667,
            0.6,
            0.6,
            0.6166666666666667,
            0.65,
            0.6166666666666667,
            0.6166666666666667,
            0.5833333333333334,
            0.6,
            0.5833333333333334,
            0.6,
            0.65,
            0.65,
            0.6166666666666667,
            0.65,
            0.6333333333333333,
            0.65,
            0.5666666666666667,
            0.6333333333333333,
            0.6,
            0.6,
            0.6666666666666666,
            0.6833333333333333,
            0.6833333333333333,
            0.65,
            0.7,
            0.6666666666666666,
            0.6166666666666667,
            0.6666666666666666,
            0.7,
            0.6833333333333333,
            0.6833333333333333,
            0.6333333333333333,
            0.6833333333333333,
            0.7
        ],
        "Max Accuracy": 0.7,
        "Final Accuracy": 0.7
    }

# %%
best_GAT =     {
        "epochs": 50,
        "lr": 0.0001,
        "layers": 4,
        "layer norm": True,
        "hidden": 128,
        "dropout": 0.3,
        "weight_decay": 0.001,
        "num heads": 4,
        "train loss arc": [
            1.7759314383069673,
            1.609530882164836,
            1.486141522632291,
            1.3875349963394303,
            1.292239851038903,
            1.197787288033093,
            1.1222564265287172,
            1.0084562073849763,
            0.9352068583791454,
            0.8565117757224168,
            0.755014962873732,
            0.6959478135278914,
            0.6247909781600659,
            0.5539566620563467,
            0.48568382899975404,
            0.4309300268389052,
            0.36971366751628615,
            0.35831816941305683,
            0.2866510862620392,
            0.2626862665133861,
            0.21596360178979618,
            0.18994382124680367,
            0.17980898044455293,
            0.16277607471808248,
            0.12590292101691983,
            0.09996155055171888,
            0.09086383540058401,
            0.15232124133387212,
            0.09997148387831961,
            0.2726298566200361,
            0.09755965665666129,
            0.061743291139403786,
            0.06281491405361521,
            0.05439985018825458,
            0.047805359526986044,
            0.21358748391165439,
            0.2071262478022618,
            0.05590328938031538,
            0.04112741974333858,
            0.05099256904556266,
            0.0316624394116161,
            0.12400183344078262,
            0.20263921008953692,
            0.034622130042040074,
            0.030137024716592957,
            0.023915708124083796,
            0.027248859572576598,
            0.18872023951388048,
            0.09033681418661293,
            0.09630380923485973
        ],
        "val loss arc": [
            1.659194110830625,
            1.5789928952852885,
            1.5334488982955614,
            1.4646489155789217,
            1.378757438560327,
            1.3413409079114595,
            1.2655327759683133,
            1.2154314642151196,
            1.1597312769542139,
            1.122573173418641,
            1.1042162630707026,
            1.0416657061005632,
            0.9836499516541759,
            0.9850129989596704,
            0.955291720572859,
            0.9688410242709021,
            0.9206372079594681,
            0.9426261201656113,
            0.8999337845637153,
            0.9748536277407159,
            0.9077527622537066,
            0.9783276429089407,
            0.9473728282066683,
            0.8303761620384952,
            0.9724428326939233,
            1.1062093445332721,
            1.3237825866478186,
            1.0030266599807267,
            1.0172716242649282,
            0.9099963387222184,
            1.06623375423369,
            1.001450496679172,
            0.9953670771210454,
            1.0161222723778338,
            1.1085353748717657,
            0.9319483810958142,
            1.0411318318947451,
            1.0916275454015705,
            1.1289170782091484,
            0.9450415654714258,
            1.0140899032989787,
            1.1654771003843052,
            1.0842217698150003,
            1.0591883435360312,
            1.1469921178679214,
            1.068817915249383,
            1.2677108229031242,
            1.0191674042260275,
            0.9415600432073309,
            1.0183435197599464
        ],
        "val accuracies": [
            0.36666666666666664,
            0.45,
            0.48333333333333334,
            0.5,
            0.5333333333333333,
            0.5,
            0.5833333333333334,
            0.6,
            0.55,
            0.6333333333333333,
            0.6666666666666666,
            0.7,
            0.7166666666666667,
            0.7166666666666667,
            0.7166666666666667,
            0.7166666666666667,
            0.7,
            0.7166666666666667,
            0.7166666666666667,
            0.7333333333333333,
            0.7,
            0.7166666666666667,
            0.7166666666666667,
            0.75,
            0.7,
            0.7,
            0.6833333333333333,
            0.7333333333333333,
            0.7166666666666667,
            0.75,
            0.7,
            0.7333333333333333,
            0.75,
            0.7333333333333333,
            0.6833333333333333,
            0.6666666666666666,
            0.7166666666666667,
            0.7,
            0.7166666666666667,
            0.7166666666666667,
            0.7333333333333333,
            0.6666666666666666,
            0.7166666666666667,
            0.7,
            0.7166666666666667,
            0.7333333333333333,
            0.65,
            0.6666666666666666,
            0.7333333333333333,
            0.7333333333333333
        ],
        "Max Accuracy": 0.75,
        "Final Accuracy": 0.7333333333333333
    }

# %%
import torch 
from models import baselineMLP, GAT, GCN
from data_processing import INPUT_DIM, OUTPUT_DIM, process_dataset

train_dataset, val_dataset, test_dataset = process_dataset()

mlp = baselineMLP(input_dim=INPUT_DIM, hidden_dim=best_mlp['hidden'],output_dim=OUTPUT_DIM,dropout=0.3)
mlp.load_state_dict(torch.load("saved_models/best_MLP_model.pth"))
mlp.eval()  


GCN_model = GCN(input_dim=INPUT_DIM, hidden=best_GCN['hidden'],output_dim=OUTPUT_DIM,num_layers=best_GCN['layers'],dropout=0.3,layer_norm=best_GCN['layer norm'])
GCN_model.load_state_dict(torch.load("saved_models/best_GCN_model.pth"))
GCN_model.eval()  


GAT_model = GAT(input_dim=INPUT_DIM, hidden_dim=best_GAT['hidden'],output_dim=OUTPUT_DIM,num_layers=best_GAT['layers'],dropout=0.3,layer_norm=best_GAT['layer norm'], num_heads=best_GAT['num heads'])
GAT_model.load_state_dict(torch.load("saved_models/best_GAT_model.pth"))
GAT_model.eval()
# Out:
# GAT(
#   (LN): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (gat1): GATConv(21, 128, heads=4)
#   (layers): ModuleList(
#     (0): GATConv(21, 128, heads=4)
#     (1-3): 3 x GATConv(128, 128, heads=4)
#   )
#   (linear): Linear(in_features=128, out_features=6, bias=True)
# )

# %%
def evaluate(model,test_dataset,baseline=False):

    model.eval()
    correct = 0 

    with torch.no_grad():  
        for graph in test_dataset:
            
            if baseline:
                out = model(graph.x)  #not training in batches
            else:
                out = model(graph.x, graph.edge_index)  #not training in batches
            
            out = out.unsqueeze(0) 

            pred = out.argmax(dim=1)

            correct += int((pred == graph.y.view(-1)))

    accuracy = correct / len(test_dataset)

    return accuracy

print(f"GCN train: {evaluate(mlp, test_dataset=train_dataset, baseline=True)}")
print(f"GCN val: {evaluate(mlp, test_dataset=val_dataset, baseline=True)}")
# Out:
# GCN train: 0.50625
# GCN val: 0.5333333333333333

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Number of trainable parameters - MLP: {count_parameters(mlp)}")
print(f"Number of trainable parameters - GCN: {count_parameters(GCN_model)}")
print(f"Number of trainable parameters - GAT: {count_parameters(GAT_model)}")
# Out:
# Number of trainable parameters - MLP: 7174
# Number of trainable parameters - GCN: 53382
# Number of trainable parameters - GAT: 212998

# %%
def evaluate(model,test_dataset,baseline=False):

    model.eval()
    correct = 0 

    with torch.no_grad():  
        for graph in test_dataset:

            out = model(graph.x, graph.edge_index)  #not training in batches
            
            out = out.unsqueeze(0) 

            pred = out.argmax(dim=1)

            correct += int((pred == graph.y.view(-1)))

    accuracy = correct / len(test_dataset)

    return accuracy

print(f"GCN train: {evaluate(GCN_model, test_dataset=train_dataset)}")
print(f"GCN val: {evaluate(GCN_model, test_dataset=val_dataset)}")
# print(f"GCN train: {evaluate(GCN_model, test_dataset=train_dataset)}")

print(f"GAT train: {evaluate(GAT_model, test_dataset=train_dataset)}")
print(f"GAT val: {evaluate(GAT_model, test_dataset=val_dataset)}")
# print(f"GAT test: {evaluate(GCN_model, test_dataset=train_dataset)}")
# Out:
# GCN train: 0.9854166666666667
# GCN val: 0.7
# GAT train: 0.9895833333333334
# GAT val: 0.7333333333333333

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

def create_confusion_matrix(model, dataset, num_classes=6):

    all_preds = []
    all_labels = []
    
    model.eval()
    with torch.no_grad():
        for graph in dataset:

            out = model(graph.x, graph.edge_index)
            
            out = out.unsqueeze(0)
            pred = out.argmax(dim=1)
            
            all_preds.append(pred.item())
            all_labels.append(graph.y.view(-1).item())
    
    y_true = np.array(all_labels)
    y_pred = np.array(all_preds)
    cm = confusion_matrix(y_true, y_pred)
    
    return cm, y_true, y_pred

# %%
cm_GCN = create_confusion_matrix(GCN_model, val_dataset)
# Out:
# (array([[ 6,  3,  1,  0,  1,  1],
#         [ 0,  6,  0,  1,  0,  0],
#         [ 1,  2,  9,  1,  1,  1],
#         [ 0,  1,  0,  8,  0,  0],
#         [ 0,  2,  0,  1,  3,  1],
#         [ 0,  0,  0,  0,  0, 10]]),
#  array([3, 1, 2, 0, 2, 0, 4, 4, 5, 5, 4, 2, 2, 5, 2, 3, 0, 0, 5, 3, 0, 5,
#         5, 2, 0, 2, 5, 0, 2, 4, 2, 2, 5, 0, 3, 3, 1, 3, 4, 0, 1, 5, 2, 2,
#         1, 1, 0, 3, 5, 2, 2, 2, 1, 4, 1, 3, 3, 0, 0, 4]),
#  array([3, 1, 2, 1, 5, 0, 3, 1, 5, 5, 4, 2, 2, 5, 2, 3, 2, 0, 5, 3, 0, 5,
#         5, 0, 1, 2, 5, 5, 2, 4, 1, 1, 5, 0, 3, 1, 1, 3, 4, 1, 1, 5, 4, 2,
#         1, 1, 0, 3, 5, 2, 3, 2, 1, 1, 3, 3, 3, 0, 4, 5]))

# %%
GCN_model.load_state_dict(torch.load("saved_models/retrained_GCN_model.pth"))
GCN_model.eval()
# Out:
# GCN test: 0.5666666666666667
# GCN test: 0.8375
